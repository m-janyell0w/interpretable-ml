# %%
import wandb
api = wandb.Api()

# run is specified by <entity>/<project>/<run_id>
run = api.run("m-janyellow/interpretable-ml/17zxenvi")

run.summary
#metrics_dataframe.to_csv("metrics.csv")
# Out:
# {'_step': 0, '_runtime': 44, '_timestamp': 1656667389, 'n_features': 10, 'Model Params': {'binning': 'quantile', 'inner_bags': 0, 'feature_names': ['yy', 'cum_return_12_7', 'ret', 'd_so', 'mm_sin', 'suv', 'd_shrout', 'mm_cos', 'rna', 'stock', 'mm_sin x d_shrout', 'yy x d_shrout', 'yy x mm_cos', 'yy x mm_sin', 'd_shrout x mm_cos', 'd_so x mm_sin', 'ret x d_shrout', 'ret x d_so', 'yy x d_so', 'cum_return_12_7 x d_shrout'], 'max_interaction_bins': 32, 'early_stopping_rounds': 37, 'mains': 'all', 'outer_bags': 8, 'random_state': 0, 'learning_rate': 0.000609840586504895, 'validation_size': 0.15, 'min_samples_leaf': 2, 'n_jobs': -2, 'max_bins': 230, 'max_leaves': 3, 'max_rounds': 3000, 'interactions': 10, 'feature_types': ['continuous', 'continuous', 'continuous', 'continuous', 'continuous', 'continuous', 'continuous', 'continuous', 'continuous', 'continuous', 'interaction', 'interaction', 'interaction', 'interaction', 'interaction', 'interaction', 'interaction', 'interaction', 'interactio
# ...

# %%
help(wandb.Api)
# Out:
# Help on class Api in module wandb.apis.public:
#
# class Api(builtins.object)
#  |  Api(overrides={}, timeout: Union[int, NoneType] = None, api_key: Union[str, NoneType] = None)
#  |
#  |  Used for querying the wandb server.
#  |
#  |  Examples:
#  |      Most common way to initialize
#  |      >>> wandb.Api()
#  |
#  |  Arguments:
#  |      overrides: (dict) You can set `base_url` if you are using a wandb server
#  |          other than https://api.wandb.ai.
#  |          You can also set defaults for `entity`, `project`, and `run`.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, overrides={}, timeout: Union[int, NoneType] = None, api_key: Union[str, NoneType] = None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  artifact(self, name, type=None)
#  |      Returns a single artifact by parsing path in the form `entity/project/run_id`.
#  |
#  |      Arguments:
# ...
